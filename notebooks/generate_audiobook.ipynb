# %%
import subprocess
import os

def check_ffmpeg_and_ffprobe():
    try:
        # Check ffmpeg
        subprocess.run(['ffmpeg', '-version'], capture_output=True, check=True)
        # Check ffprobe 
        subprocess.run(['ffprobe', '-version'], capture_output=True, check=True)
        return True
    except (subprocess.SubprocessError, FileNotFoundError):
        print("FFmpeg and/or FFprobe are not installed or not in PATH. Please run ./setup.sh from the project root to install them.\n"
              "Alternatively, you can install manually:\n"
              "- On macOS: brew install ffmpeg\n"
              "- On Ubuntu/Debian: sudo apt install ffmpeg\n"
              "- On Windows: Download from https://ffmpeg.org/download.html")
        
        return False

# Run the function and print result
is_ffmpeg_installed = check_ffmpeg_and_ffprobe()
print(f"FFmpeg and FFprobe are installed: {is_ffmpeg_installed}")
# Out:
# FFmpeg and FFprobe are installed: True

# %%
import yt_dlp

def download_youtube_audio(url, output_path=None):
    """
    Download audio from a YouTube video or playlist
    
    Args:
        url (str): YouTube video or playlist URL
        output_path (str, optional): Path where the audio should be saved.
            For single videos: filename.mp3
            For playlists: playlist_name/video_title.mp3
    """
    # First check if ffmpeg and ffprobe are installed
    if not check_ffmpeg_and_ffprobe():
        return
        
    # Get ffmpeg location
    try:
        ffmpeg_path = subprocess.check_output(['which', 'ffmpeg']).decode().strip()
        ffmpeg_dir = os.path.dirname(ffmpeg_path)
    except subprocess.SubprocessError:
        print("Could not locate ffmpeg. Please ensure it's installed and in your PATH")
        return

    # Create downloads directory if it doesn't exist
    downloads_dir = os.path.join(os.path.dirname(os.getcwd()), 'downloads')
    os.makedirs(downloads_dir, exist_ok=True)

    # Configure yt-dlp options
    ydl_opts = {
        'format': 'bestaudio/best',
        'postprocessors': [{
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '192',
        }],
        'ffmpeg_location': ffmpeg_dir,  # Add ffmpeg directory location
        'quiet': False,
        'no_warnings': False,
    }

    try:
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            # Extract info first to determine if it's a playlist
            info = ydl.extract_info(url, download=False)
            
            if 'entries' in info:  # It's a playlist
                # Create playlist directory
                playlist_name = info.get('title', 'playlist')
                playlist_dir = os.path.join(downloads_dir, playlist_name)
                os.makedirs(playlist_dir, exist_ok=True)
                
                # Set output template for playlist items
                ydl_opts['outtmpl'] = os.path.join(playlist_dir, '%(title)s.%(ext)s')
            else:  # Single video
                if output_path:
                    ydl_opts['outtmpl'] = os.path.join(downloads_dir, output_path)
                else:
                    ydl_opts['outtmpl'] = os.path.join(downloads_dir, '%(title)s.%(ext)s')
            
            # Download with updated options
            with yt_dlp.YoutubeDL(ydl_opts) as ydl_download:
                ydl_download.download([url])
                
        print("Audio download completed successfully!")
    except Exception as e:
        print(f"An error occurred: {str(e)}")

# Example usage

# Can be video url or playlist url
video_url = "https://www.youtube.com/playlist?list=PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS"
download_youtube_audio(video_url)

# If you want to specify an output path (for single videos only):
# download_youtube_audio("https://www.youtube.com/watch?v=example", "my_audio.mp3")
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS: Downloading webpage
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Toad Voice Clips
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# [youtube:tab] Playlist Toad Voice Clips: Downloading 24 items of 24
# [download] Downloading item 1 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wQ3Ijr-Qhz4
# [youtube] wQ3Ijr-Qhz4: Downloading webpage
# [youtube] wQ3Ijr-Qhz4: Downloading ios player API JSON
# [youtube] wQ3Ijr-Qhz4: Downloading mweb player API JSON
# [youtube] wQ3Ijr-Qhz4: Downloading m3u8 information
# [download] Downloading item 2 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aoKvzcK06AE
# [youtube] aoKvzcK06AE: Downloading webpage
# [youtube] aoKvzcK06AE: Downloading ios player API JSON
# [youtube] aoKvzcK06AE: Downloading mweb player API JSON
# [youtube] aoKvzcK06AE: Downloading m3u8 information
# [download] Downloading item 3 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Y50lq-1JrSQ
# [youtube] Y50lq-1JrSQ: Downloading webpage
# [youtube] Y50lq-1JrSQ: Downloading ios player API JSON
# [youtube] Y50lq-1JrSQ: Downloading mweb player API JSON
# [youtube] Y50lq-1JrSQ: Downloading m3u8 information
# [download] Downloading item 4 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JyvEzfVK3Oo
# [youtube] JyvEzfVK3Oo: Downloading webpage
# [youtube] JyvEzfVK3Oo: Downloading ios player API JSON
# [youtube] JyvEzfVK3Oo: Downloading mweb player API JSON
# [youtube] JyvEzfVK3Oo: Downloading m3u8 information
# [download] Downloading item 5 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L6CKu-Y4c3M
# [youtube] L6CKu-Y4c3M: Downloading webpage
# [youtube] L6CKu-Y4c3M: Downloading ios player API JSON
# [youtube] L6CKu-Y4c3M: Downloading mweb player API JSON
# [youtube] L6CKu-Y4c3M: Downloading m3u8 information
# [download] Downloading item 6 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=--noNnJavMg
# [youtube] --noNnJavMg: Downloading webpage
# [youtube] --noNnJavMg: Downloading ios player API JSON
# [youtube] --noNnJavMg: Downloading mweb player API JSON
# [youtube] --noNnJavMg: Downloading m3u8 information
# [download] Downloading item 7 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gGvaPl_6OYg
# [youtube] gGvaPl_6OYg: Downloading webpage
# [youtube] gGvaPl_6OYg: Downloading ios player API JSON
# [youtube] gGvaPl_6OYg: Downloading mweb player API JSON
# [youtube] gGvaPl_6OYg: Downloading m3u8 information
# [download] Downloading item 8 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=361OD0eBebc
# [youtube] 361OD0eBebc: Downloading webpage
# [youtube] 361OD0eBebc: Downloading ios player API JSON
# [youtube] 361OD0eBebc: Downloading mweb player API JSON
# [youtube] 361OD0eBebc: Downloading m3u8 information
# [download] Downloading item 9 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FmEyi_RDzro
# [youtube] FmEyi_RDzro: Downloading webpage
# [youtube] FmEyi_RDzro: Downloading ios player API JSON
# [youtube] FmEyi_RDzro: Downloading mweb player API JSON
# [youtube] FmEyi_RDzro: Downloading m3u8 information
# [download] Downloading item 10 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=j2ylnqY9i24
# [youtube] j2ylnqY9i24: Downloading webpage
# [youtube] j2ylnqY9i24: Downloading ios player API JSON
# [youtube] j2ylnqY9i24: Downloading mweb player API JSON
# [youtube] j2ylnqY9i24: Downloading m3u8 information
# [download] Downloading item 11 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IHcNqhON-Ug
# [youtube] IHcNqhON-Ug: Downloading webpage
# [youtube] IHcNqhON-Ug: Downloading ios player API JSON
# [youtube] IHcNqhON-Ug: Downloading mweb player API JSON
# [youtube] IHcNqhON-Ug: Downloading m3u8 information
# [download] Downloading item 12 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sn8Hys3ILtk
# [youtube] sn8Hys3ILtk: Downloading webpage
# [youtube] sn8Hys3ILtk: Downloading ios player API JSON
# [youtube] sn8Hys3ILtk: Downloading mweb player API JSON
# [youtube] sn8Hys3ILtk: Downloading m3u8 information
# [download] Downloading item 13 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2m4X4ePTfdQ
# [youtube] 2m4X4ePTfdQ: Downloading webpage
# [youtube] 2m4X4ePTfdQ: Downloading ios player API JSON
# [youtube] 2m4X4ePTfdQ: Downloading mweb player API JSON
# [youtube] 2m4X4ePTfdQ: Downloading m3u8 information
# [download] Downloading item 14 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=h66gvuLJ1pg
# [youtube] h66gvuLJ1pg: Downloading webpage
# [youtube] h66gvuLJ1pg: Downloading ios player API JSON
# [youtube] h66gvuLJ1pg: Downloading mweb player API JSON
# [youtube] h66gvuLJ1pg: Downloading m3u8 information
# [download] Downloading item 15 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T4hfQq2hlhA
# [youtube] T4hfQq2hlhA: Downloading webpage
# [youtube] T4hfQq2hlhA: Downloading ios player API JSON
# [youtube] T4hfQq2hlhA: Downloading mweb player API JSON
# [youtube] T4hfQq2hlhA: Downloading m3u8 information
# [download] Downloading item 16 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5I04T6_XhMo
# [youtube] 5I04T6_XhMo: Downloading webpage
# [youtube] 5I04T6_XhMo: Downloading ios player API JSON
# [youtube] 5I04T6_XhMo: Downloading mweb player API JSON
# [youtube] 5I04T6_XhMo: Downloading m3u8 information
# [download] Downloading item 17 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qIi8NA3GwLM
# [youtube] qIi8NA3GwLM: Downloading webpage
# [youtube] qIi8NA3GwLM: Downloading ios player API JSON
# [youtube] qIi8NA3GwLM: Downloading mweb player API JSON
# [youtube] qIi8NA3GwLM: Downloading m3u8 information
# [download] Downloading item 18 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=b09Uo7JnVK0
# [youtube] b09Uo7JnVK0: Downloading webpage
# [youtube] b09Uo7JnVK0: Downloading ios player API JSON
# [youtube] b09Uo7JnVK0: Downloading mweb player API JSON
# [youtube] b09Uo7JnVK0: Downloading m3u8 information
# [download] Downloading item 19 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QUKaGJ0O3bw
# [youtube] QUKaGJ0O3bw: Downloading webpage
# [youtube] QUKaGJ0O3bw: Downloading ios player API JSON
# [youtube] QUKaGJ0O3bw: Downloading mweb player API JSON
# [youtube] QUKaGJ0O3bw: Downloading m3u8 information
# [download] Downloading item 20 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TqPApPy7rpE
# [youtube] TqPApPy7rpE: Downloading webpage
# [youtube] TqPApPy7rpE: Downloading ios player API JSON
# [youtube] TqPApPy7rpE: Downloading mweb player API JSON
# [youtube] TqPApPy7rpE: Downloading m3u8 information
# [download] Downloading item 21 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4jEnJ7sOHoc
# [youtube] 4jEnJ7sOHoc: Downloading webpage
# [youtube] 4jEnJ7sOHoc: Downloading ios player API JSON
# [youtube] 4jEnJ7sOHoc: Downloading mweb player API JSON
# [youtube] 4jEnJ7sOHoc: Downloading m3u8 information
# [download] Downloading item 22 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jBtljwrGA0Y
# [youtube] jBtljwrGA0Y: Downloading webpage
# [youtube] jBtljwrGA0Y: Downloading ios player API JSON
# [youtube] jBtljwrGA0Y: Downloading mweb player API JSON
# [youtube] jBtljwrGA0Y: Downloading m3u8 information
# [download] Downloading item 23 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=X8qZ_95aH1c
# [youtube] X8qZ_95aH1c: Downloading webpage
# [youtube] X8qZ_95aH1c: Downloading ios player API JSON
# [youtube] X8qZ_95aH1c: Downloading mweb player API JSON
# [youtube] X8qZ_95aH1c: Downloading m3u8 information
# [download] Downloading item 24 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=A5_cCte4qtY
# [youtube] A5_cCte4qtY: Downloading webpage
# [youtube] A5_cCte4qtY: Downloading ios player API JSON
# [youtube] A5_cCte4qtY: Downloading mweb player API JSON
# [youtube] A5_cCte4qtY: Downloading m3u8 information
# [download] Finished downloading playlist: Toad Voice Clips
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS: Downloading webpage
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Toad Voice Clips
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# [youtube:tab] PLT7YQtwNLtQ1NVxBXfSkkoU5V3kZjU2uS page 1: Downloading API JSON
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# [youtube:tab] Playlist Toad Voice Clips: Downloading 24 items of 24
# [download] Downloading item 1 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=wQ3Ijr-Qhz4
# [youtube] wQ3Ijr-Qhz4: Downloading webpage
# [youtube] wQ3Ijr-Qhz4: Downloading ios player API JSON
# [youtube] wQ3Ijr-Qhz4: Downloading mweb player API JSON
# [youtube] wQ3Ijr-Qhz4: Downloading m3u8 information
# [info] wQ3Ijr-Qhz4: Downloading 1 format(s): 251
# [download] /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 8 - All Toad Sound Effects ⧸ Voice Clips.webm has already been downloaded
# [download] 100% of    1.04MiB
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 8 - All Toad Sound Effects ⧸ Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 8 - All Toad Sound Effects ⧸ Voice Clips.webm (pass -k to keep)
# [download] Downloading item 2 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aoKvzcK06AE
# [youtube] aoKvzcK06AE: Downloading webpage
# [youtube] aoKvzcK06AE: Downloading ios player API JSON
# [youtube] aoKvzcK06AE: Downloading mweb player API JSON
# [youtube] aoKvzcK06AE: Downloading m3u8 information
# [info] aoKvzcK06AE: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros Wii - Toad Voice Clips.webm
# [download] 100% of    1.27MiB in 00:00:01 at 778.76KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros Wii - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros Wii - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 3 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Y50lq-1JrSQ
# [youtube] Y50lq-1JrSQ: Downloading webpage
# [youtube] Y50lq-1JrSQ: Downloading ios player API JSON
# [youtube] Y50lq-1JrSQ: Downloading mweb player API JSON
# [youtube] Y50lq-1JrSQ: Downloading m3u8 information
# [info] Y50lq-1JrSQ: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 10 - Toad Sound Effects ⧸ Voice Clips.webm
# [download] 100% of  991.94KiB in 00:00:01 at 531.22KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 10 - Toad Sound Effects ⧸ Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 10 - Toad Sound Effects ⧸ Voice Clips.webm (pass -k to keep)
# [download] Downloading item 4 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JyvEzfVK3Oo
# [youtube] JyvEzfVK3Oo: Downloading webpage
# [youtube] JyvEzfVK3Oo: Downloading ios player API JSON
# [youtube] JyvEzfVK3Oo: Downloading mweb player API JSON
# [youtube] JyvEzfVK3Oo: Downloading m3u8 information
# [info] JyvEzfVK3Oo: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros U Deluxe - Yellow Toad Voice Clips.webm
# [download] 100% of  707.93KiB in 00:00:01 at 627.36KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros U Deluxe - Yellow Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros U Deluxe - Yellow Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 5 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=L6CKu-Y4c3M
# [youtube] L6CKu-Y4c3M: Downloading webpage
# [youtube] L6CKu-Y4c3M: Downloading ios player API JSON
# [youtube] L6CKu-Y4c3M: Downloading mweb player API JSON
# [youtube] L6CKu-Y4c3M: Downloading m3u8 information
# [info] L6CKu-Y4c3M: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros U Deluxe - Blue Toad Voice Clips.webm
# [download] 100% of  677.28KiB in 00:00:01 at 533.47KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros U Deluxe - Blue Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/New Super Mario Bros U Deluxe - Blue Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 6 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=--noNnJavMg
# [youtube] --noNnJavMg: Downloading webpage
# [youtube] --noNnJavMg: Downloading ios player API JSON
# [youtube] --noNnJavMg: Downloading mweb player API JSON
# [youtube] --noNnJavMg: Downloading m3u8 information
# [info] --noNnJavMg: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 8 - Toad Voice Clips.webm
# [download] 100% of  755.51KiB in 00:00:01 at 519.52KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 8 - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 8 - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 7 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gGvaPl_6OYg
# [youtube] gGvaPl_6OYg: Downloading webpage
# [youtube] gGvaPl_6OYg: Downloading ios player API JSON
# [youtube] gGvaPl_6OYg: Downloading mweb player API JSON
# [youtube] gGvaPl_6OYg: Downloading m3u8 information
# [info] gGvaPl_6OYg: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart Wii - Toad Voice Clips.webm
# [download] 100% of    1.75MiB in 00:00:02 at 798.61KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart Wii - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart Wii - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 8 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=361OD0eBebc
# [youtube] 361OD0eBebc: Downloading webpage
# [youtube] 361OD0eBebc: Downloading ios player API JSON
# [youtube] 361OD0eBebc: Downloading mweb player API JSON
# [youtube] 361OD0eBebc: Downloading m3u8 information
# [info] 361OD0eBebc: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 8 Deluxe - Toad Voice Clips.webm
# [download] 100% of    1.11MiB in 00:00:02 at 558.29KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 8 Deluxe - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 8 Deluxe - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 9 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FmEyi_RDzro
# [youtube] FmEyi_RDzro: Downloading webpage
# [youtube] FmEyi_RDzro: Downloading ios player API JSON
# [youtube] FmEyi_RDzro: Downloading mweb player API JSON
# [youtube] FmEyi_RDzro: Downloading m3u8 information
# [info] FmEyi_RDzro: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Advance - Toad Voice Clips.webm
# [download] 100% of  634.38KiB in 00:00:01 at 460.81KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Advance - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Advance - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 10 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=j2ylnqY9i24
# [youtube] j2ylnqY9i24: Downloading webpage
# [youtube] j2ylnqY9i24: Downloading ios player API JSON
# [youtube] j2ylnqY9i24: Downloading mweb player API JSON
# [youtube] j2ylnqY9i24: Downloading m3u8 information
# [info] j2ylnqY9i24: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 7 - Toad Voice Clips.webm
# [download] 100% of  427.54KiB in 00:00:01 at 327.00KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 7 - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart 7 - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 11 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IHcNqhON-Ug
# [youtube] IHcNqhON-Ug: Downloading webpage
# [youtube] IHcNqhON-Ug: Downloading ios player API JSON
# [youtube] IHcNqhON-Ug: Downloading mweb player API JSON
# [youtube] IHcNqhON-Ug: Downloading m3u8 information
# [info] IHcNqhON-Ug: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Odyssey - Captain Toad Voice Clips.webm
# [download] 100% of  354.45KiB in 00:00:01 at 315.59KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Odyssey - Captain Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Odyssey - Captain Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 12 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=sn8Hys3ILtk
# [youtube] sn8Hys3ILtk: Downloading webpage
# [youtube] sn8Hys3ILtk: Downloading ios player API JSON
# [youtube] sn8Hys3ILtk: Downloading mweb player API JSON
# [youtube] sn8Hys3ILtk: Downloading m3u8 information
# [info] sn8Hys3ILtk: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 9 - Toad Voice Clips.webm
# [download] 100% of  492.01KiB in 00:00:01 at 382.15KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 9 - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 9 - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 13 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=2m4X4ePTfdQ
# [youtube] 2m4X4ePTfdQ: Downloading webpage
# [youtube] 2m4X4ePTfdQ: Downloading ios player API JSON
# [youtube] 2m4X4ePTfdQ: Downloading mweb player API JSON
# [youtube] 2m4X4ePTfdQ: Downloading m3u8 information
# [info] 2m4X4ePTfdQ: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart DS - Princess Peach & Toad Voice Clips.webm
# [download] 100% of  461.75KiB in 00:00:01 at 371.49KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart DS - Princess Peach & Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart DS - Princess Peach & Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 14 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=h66gvuLJ1pg
# [youtube] h66gvuLJ1pg: Downloading webpage
# [youtube] h66gvuLJ1pg: Downloading ios player API JSON
# [youtube] h66gvuLJ1pg: Downloading mweb player API JSON
# [youtube] h66gvuLJ1pg: Downloading m3u8 information
# [info] h66gvuLJ1pg: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Golf Toadstool Tour - Toad Voice Clips.webm
# [download] 100% of    1.26MiB in 00:00:02 at 586.95KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Golf Toadstool Tour - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Golf Toadstool Tour - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 15 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T4hfQq2hlhA
# [youtube] T4hfQq2hlhA: Downloading webpage
# [youtube] T4hfQq2hlhA: Downloading ios player API JSON
# [youtube] T4hfQq2hlhA: Downloading mweb player API JSON
# [youtube] T4hfQq2hlhA: Downloading m3u8 information
# [info] T4hfQq2hlhA: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 5 - Toad Voice Clips.webm
# [download] 100% of  597.26KiB in 00:00:01 at 564.27KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 5 - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Party 5 - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 16 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5I04T6_XhMo
# [youtube] 5I04T6_XhMo: Downloading webpage
# [youtube] 5I04T6_XhMo: Downloading ios player API JSON
# [youtube] 5I04T6_XhMo: Downloading mweb player API JSON
# [youtube] 5I04T6_XhMo: Downloading m3u8 information
# [info] 5I04T6_XhMo: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart Tour - Toad Voice Clips.webm
# [download] 100% of    1.32MiB in 00:00:02 at 609.55KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart Tour - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Kart Tour - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 17 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=qIi8NA3GwLM
# [youtube] qIi8NA3GwLM: Downloading webpage
# [youtube] qIi8NA3GwLM: Downloading ios player API JSON
# [youtube] qIi8NA3GwLM: Downloading mweb player API JSON
# [youtube] qIi8NA3GwLM: Downloading m3u8 information
# [info] qIi8NA3GwLM: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Maker 2 - Toad Voice Clips ⧸ Sound Effects (New Super Mario Bros U).webm
# [download] 100% of  535.72KiB in 00:00:00 at 578.17KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Maker 2 - Toad Voice Clips ⧸ Sound Effects (New Super Mario Bros U).mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Maker 2 - Toad Voice Clips ⧸ Sound Effects (New Super Mario Bros U).webm (pass -k to keep)
# [download] Downloading item 18 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=b09Uo7JnVK0
# [youtube] b09Uo7JnVK0: Downloading webpage
# [youtube] b09Uo7JnVK0: Downloading ios player API JSON
# [youtube] b09Uo7JnVK0: Downloading mweb player API JSON
# [youtube] b09Uo7JnVK0: Downloading m3u8 information
# [info] b09Uo7JnVK0: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Tennis Aces - Toad Voice Clips.webm
# [download] 100% of    1.21MiB in 00:00:02 at 542.21KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Tennis Aces - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Tennis Aces - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 19 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=QUKaGJ0O3bw
# [youtube] QUKaGJ0O3bw: Downloading webpage
# [youtube] QUKaGJ0O3bw: Downloading ios player API JSON
# [youtube] QUKaGJ0O3bw: Downloading mweb player API JSON
# [youtube] QUKaGJ0O3bw: Downloading m3u8 information
# [info] QUKaGJ0O3bw: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario & Luigi： Paper Jam - Toad Voice Clips.webm
# [download] 100% of  346.95KiB in 00:00:01 at 331.79KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario & Luigi： Paper Jam - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario & Luigi： Paper Jam - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 20 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=TqPApPy7rpE
# [youtube] TqPApPy7rpE: Downloading webpage
# [youtube] TqPApPy7rpE: Downloading ios player API JSON
# [youtube] TqPApPy7rpE: Downloading mweb player API JSON
# [youtube] TqPApPy7rpE: Downloading m3u8 information
# [info] TqPApPy7rpE: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Maker 2 - Toad Voice Clips ⧸ Sound Effects (3D World).webm
# [download] 100% of    1.07MiB in 00:00:02 at 508.36KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Maker 2 - Toad Voice Clips ⧸ Sound Effects (3D World).mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Maker 2 - Toad Voice Clips ⧸ Sound Effects (3D World).webm (pass -k to keep)
# [download] Downloading item 21 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4jEnJ7sOHoc
# [youtube] 4jEnJ7sOHoc: Downloading webpage
# [youtube] 4jEnJ7sOHoc: Downloading ios player API JSON
# [youtube] 4jEnJ7sOHoc: Downloading mweb player API JSON
# [youtube] 4jEnJ7sOHoc: Downloading m3u8 information
# [info] 4jEnJ7sOHoc: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario + Rabbids Kingdom Battle - Toad Voice Clips.webm
# [download] 100% of  300.27KiB in 00:00:00 at 515.26KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario + Rabbids Kingdom Battle - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario + Rabbids Kingdom Battle - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 22 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=jBtljwrGA0Y
# [youtube] jBtljwrGA0Y: Downloading webpage
# [youtube] jBtljwrGA0Y: Downloading ios player API JSON
# [youtube] jBtljwrGA0Y: Downloading mweb player API JSON
# [youtube] jBtljwrGA0Y: Downloading m3u8 information
# [info] jBtljwrGA0Y: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Sports Mix - Toad Voice Clips.webm
# [download] 100% of  483.20KiB in 00:00:01 at 424.01KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Sports Mix - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Sports Mix - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 23 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=X8qZ_95aH1c
# [youtube] X8qZ_95aH1c: Downloading webpage
# [youtube] X8qZ_95aH1c: Downloading ios player API JSON
# [youtube] X8qZ_95aH1c: Downloading mweb player API JSON
# [youtube] X8qZ_95aH1c: Downloading m3u8 information
# [info] X8qZ_95aH1c: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Tennis Ultra Smash - Toad Voice Clips.webm
# [download] 100% of  397.35KiB in 00:00:00 at 527.52KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Tennis Ultra Smash - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Mario Tennis Ultra Smash - Toad Voice Clips.webm (pass -k to keep)
# [download] Downloading item 24 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=A5_cCte4qtY
# [youtube] A5_cCte4qtY: Downloading webpage
# [youtube] A5_cCte4qtY: Downloading ios player API JSON
# [youtube] A5_cCte4qtY: Downloading mweb player API JSON
# [youtube] A5_cCte4qtY: Downloading m3u8 information
# [info] A5_cCte4qtY: Downloading 1 format(s): 251
# [download] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Advance - Toad Voice Clips.webm
# [download] 100% of  648.25KiB in 00:00:01 at 510.40KiB/s
# [ExtractAudio] Destination: /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Advance - Toad Voice Clips.mp3
# Deleting original file /Users/suchintan/Development/audiobook-generator/downloads/Toad Voice Clips/Super Mario Advance - Toad Voice Clips.webm (pass -k to keep)
# [download] Finished downloading playlist: Toad Voice Clips
# Audio download completed successfully!
